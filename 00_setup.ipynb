# %% [markdown]
# <a href="https://colab.research.google.com/github/Cav1on/ml-playground/blob/main/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1: Setting up the environment
# Hello! This is my first project as part of my 4-mouth ML learning plan. Here is i am testing Python, importing basic libraries and connecting to the Google Drive.

# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import numpy as np
import pandas as pd
import torch

print(f"Version Python: {sys.version}")
print(f"Version NumPy: {np.__version__}")
print(f"Version Pandas: {pd.__version__}")
print(f"Is the GPU available: {torch.cuda.is_available()}")
# Out:
# Version Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Version NumPy: 2.0.2
# Version Pandas: 2.2.2
# Is the GPU available: False
